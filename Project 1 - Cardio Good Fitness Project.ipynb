# %%
#importing libraries
import pandas as pd
from pandas import read_csv
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes = True)
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Looking at the data

# %%
#take a peep at the data
dataframe = pd.read_csv(r'C:/Users/Chidinma Anunike/Desktop/Great Learning/Visualisation Assessment/CardioGoodFitness.csv')
dataframe.head()
#this shows the first five rows of the dataset
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
df1 = (dataframe['Gender'] == 'Male') | (dataframe['Income'] >= 40000) 
dataframe[df1]
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18   Male         14        Single      3        4   29562
# 1     TM195   19   Male         15        Single      2        3   31836
# 3     TM195   19   Male         12        Single      3        3   32973
# 4     TM195   20   Male         13     Partnered      4        2   35247
# 7     TM195   21   Male         13        Single      3        3   32973
# ..      ...  ...    ...        ...           ...    ...      ...     ...
# 175   TM798   40   Male         21        Single      6        5   83416
# 176   TM798   42   Male         18        Single      5        4   89641
# 177   TM798   45   Male         16        Single      5        5   90886
# 178   TM798   47   Male         18     Partnered      4        5  104581
# 179   TM798   48   Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 3       85
# 4       47
# 7       85
# ..     ...
# ...

# %%
df2 = sum((dataframe['Gender'] == 'Female') | (dataframe['Income'] >= 30000))
df2
# Out:
# 179

# %%
dataframe['Product'].unique()
# Out:
# array(['TM195', 'TM498', 'TM798'], dtype=object)

# %%
dataframe.columns
#Shows the all the columns in the dataset
# Out:
# Index(['Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage',
#        'Fitness', 'Income', 'Miles'],
#       dtype='object')

# %% [markdown]
# #### Looking at the dimension of the data

# %%
dataframe.shape
# This shows that there are 180 rows and 9 columns(variables) in the dataset
# Out:
# (180, 9)

# %%
#to understand how many unique products we have
dataframe['Product'].unique()
#Show we have three unique products
# Out:
# array(['TM195', 'TM498', 'TM798'], dtype=object)

# %%
dataframe.info()
#Shows the different data type in each column of the dataset. 
#Product, Gender and Marital_Status are of type object indicating they are categorical variables while the other variables are all integers indicating they are numeric
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
#To make sure there are no missing values in my dataset
dataframe.isnull().sum()
#results indicate there are no missing values
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %% [markdown]
# #### Descriptive Statistics

# %%
#to get an overview of the descriptive statistics of my dataset
dataframe.describe()
#Returns statistics of all numerical variables
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
dataframe.describe(include = 'all')
#columns with categorical variable returned NaN. Example 'Product' is a categoricl variable and as such the mean of the products will return NaN.
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      TM195         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %%
dataframe.groupby('Product').size()
# To get an idea of the distribution of the attribute 'Product'.
#Shows there are 3 unique products listed below as well as the number of occurrence for each product
# Out:
# Product
# TM195    80
# TM498    60
# TM798    40
# dtype: int64

# %%
# View relationships between various attributes
dataframe.corr('pearson')
# A correlation of -1 or 1 shows a full negative or positive correlation respectively. 
# Whereas a value of 0 shows no correlation at all.
# Out:
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.280496  0.015064  0.061105  0.513414  0.036618
# Education  0.280496   1.000000  0.395155  0.410581  0.625827  0.307284
# Usage      0.015064   0.395155  1.000000  0.668606  0.519537  0.759130
# Fitness    0.061105   0.410581  0.668606  1.000000  0.535005  0.785702
# Income     0.513414   0.625827  0.519537  0.535005  1.000000  0.543473
# Miles      0.036618   0.307284  0.759130  0.785702  0.543473  1.000000

# %%
#Another type of correlation is the Spearman Rank correlation
dataframe.corr('spearman')
#Looking at the results we can see that both correlation methods produce very similar values
# Out:
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.332769  0.031330  0.063275  0.683120  0.025457
# Education  0.332769   1.000000  0.380321  0.390246  0.616526  0.300469
# Usage      0.031330   0.380321  1.000000  0.643817  0.372912  0.758502
# Fitness    0.063275   0.390246  0.643817  1.000000  0.396511  0.816037
# Income     0.683120   0.616526  0.372912  0.396511  1.000000  0.356775
# Miles      0.025457   0.300469  0.758502  0.816037  0.356775  1.000000

# %%
#Another type of correlation is the Spearman Rank correlation
dataframe.corr('kendall')
#The results show that the corelation using kendall show slightly lower values for the variables compared to both the pearson and spearman method
#Pearson and Spearman corelation produce very similar values and are very comparable to each other
#Kendall methods works best on ranked and non-parametric or discontinous data
# Out:
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.258464  0.026296  0.049028  0.530537  0.018122
# Education  0.258464   1.000000  0.326301  0.338005  0.496594  0.238748
# Usage      0.026296   0.326301  1.000000  0.570850  0.284609  0.642191
# Fitness    0.049028   0.338005  0.570850  1.000000  0.307114  0.701554
# Income     0.530537   0.496594  0.284609  0.307114  1.000000  0.249820
# Miles      0.018122   0.238748  0.642191  0.701554  0.249820  1.000000

# %%
dataframe.skew()
#We will visualise the skewness of the data later using distplot
# Out:
# Age          0.982161
# Education    0.622294
# Usage        0.739494
# Fitness      0.454800
# Income       1.291785
# Miles        1.724497
# dtype: float64

# %% [markdown]
# ### Data Visualization

# %% [markdown]
# #### Univariate Analysis

# %%
sns.distplot(dataframe['Miles']); #kde=False, rug = True);

# %%
sns.distplot(dataframe['Age']);

# %%
sns.distplot(dataframe['Education'], rug = True);

# %%
sns.distplot(dataframe['Income'], );#kde=False, rug = True);

# %%
sns.distplot(dataframe['Fitness'], );#kde=False, rug = True);

# %%
sns.distplot(dataframe['Usage'], );#kde=False, rug = True);

# %%
sns.jointplot(dataframe['Age'], dataframe['Fitness']);
#This chart is not as illustrative as it could be and should not be used to compare the two variables

# %%
sns.jointplot(dataframe['Age'], dataframe['Income']);
#the graph shows a positive correlation between age and income

# %%
dataframe.plot(kind='density', subplots=True, layout=(3,3), sharex=False)
plt.show()

# %% [markdown]
# Density plots are another way of getting a quick idea of the distribution of each attribute. The
# plots look like an abstracted histogram with a smooth curve drawn through the top of each bin,
# much like your eye tried to do with the histograms. This give an idea as to the skewness of the variables in the dataset

# %% [markdown]
# ##### Boxplots
# Provides a way of statistically representing the distribution of the data using five main dimensions - medium, minimum, maximum, first and third quartiles.
#
# Boxplots summarize the distribution of each attribute, drawing a line for the median (middle value) and a box around the 25th and 75th percentiles (the middle 50% of the data). The whiskers give an idea of the spread of the data and dots outside of the whiskers show candidate outlier values.

# %%
sns.boxplot(dataframe['Income'], dataframe['Product']);

# %%
sns.boxplot(dataframe['Miles'], dataframe['Product']);

# %%
sns.boxplot(dataframe['Miles'], dataframe['Product']);
#The median for the three products about 48000, 49000 and 77000 for the products TM195, TM498 and TM798 respectively
#Only product TM498 shows outliers in the data: one below the minimum value and the other above the maximum value

# %%
sns.boxplot(dataframe['Income'], dataframe['Product']);
#people in the higher income bracket favour product TM798
#The median for the three products is approximately 48000, 49000 and 77000 for the products TM195, TM498 and TM798 respectively
#Only product TM498 shows outliers in the data: one below the minimum value and the other above the maximum value

# %%
sns.boxplot(dataframe['Education'], dataframe['Product']);
#people with higher education also favour product TM798 which could be corelated to the fact that 
#people that are more educated are more likey to make more money or people that are more educated are more likely 
#to be interested in the products and things like durability and usage rather than just aesthetics

# %%
dataframe['Education'].median()
#This calculation was done to understand where the median education lies.
#Looking at the result of the median, it lies on the 25th percentile of the product TM798 and on the 75th percentile of products TM498 and TM195
# Out:
# 16.0

# %%
sns.boxplot(dataframe['Usage'], dataframe['Product']);

# %%
dataframe['Usage'].median()
# Out:
# 3.0

# %%
dataframe.groupby('Gender').size()
# Out:
# Gender
# Female     76
# Male      104
# dtype: int64

# %%
sns.boxplot(dataframe['Gender'], dataframe['Income']);

# %% [markdown]
# #### Categorical Variables

# %%
sns.stripplot(dataframe['Product'], dataframe['Miles']); #dataframe['Income']);
#this displays teh relationship between the the attributes product and miles.
#Users with product TM798 get more mileage out of the product

# %%
sns.stripplot(dataframe['Product'], dataframe['Income']);
#this displays the relationship between the the attributes product and Income.
#Users in the higher income bracket favour product TM798
#Users earning less than 48000 almost never buy product TM798 which could suggest it is a high end product

# %%
sns.swarmplot(dataframe['MaritalStatus'], dataframe['Income']);
#this is another representation of categorical variables. Other are shown further down

# %%
sns.catplot(x = 'Product', y = 'Income', hue = 'MaritalStatus', col = 'Gender', data = dataframe, kind = 'bar');

# %% [markdown]
# The graph shows that the high income earners are more apt to buy product TM798 and Partnered couples are more likely to buy Product TM798

# %%
sns.catplot(x = 'Product', y = 'Miles', hue = 'Gender', col = 'MaritalStatus', data = dataframe, kind = 'point');

# %%
sns.catplot(x = 'Product', y = 'Usage', hue = 'MaritalStatus', col = 'Gender', data = dataframe, kind = 'violin');

# %% [markdown]
# #### Multivariate Analysis

# %%
sns.pairplot(dataframe);

# %% [markdown]
# With the pairwise plot we can visualise a lot of the variables in the dataset as it provides a quick visual image of the dataset before more exploratory analysis.
# As we can see, there is a stong corelation between income and age, Income and Miles, Usage and Mile and Fitness and Miles.
# There is also no corelation between some variables such as Fitness and Age, Education and Fitness

# %%
sns.lmplot(y="Income", x = 'Education', data = dataframe);

# %%
sns.lmplot(y="Miles", x = 'Income', data = dataframe);

# %% [markdown]
# There is a positive corelation between income and age as well as between income and miles. The corelation is not the strongest at 0.5 however there is a relationship between income and miles. The relationship is stronger for income and age at 0.7 which is closer to perfect corelation of 1 than 0.5

# %%
plt.figure(figsize = (10,5))
sns.heatmap(dataframe.corr('spearman'), annot = True, linewidths = 0.5, fmt = '.1f', center = 1);

# %% [markdown]
# The result of the heat map shows that there is a strong positive corelation between miles and usage, miles and fitness, usage and fitness and education and income. The corelation is not as strong in education and income as it is 0.6 compared to the other which are 0.7 and 0.8

# %% [markdown]
# #### Note
# Pie charts are not usually the best for data visualisation as they fail to accurately display data with any consistency however it does provide good visualisation of the variables. In this chart, the pie chart below does not accurately portray the combinations for either Income and Products. Its not clear how the income affects the product as product TM195 appears to have  the largest sector

# %%
dataframe['Income'].groupby(dataframe['Product'], axis = 0).sum().plot(kind = 'pie');

# %%
dataframe['Miles'].groupby(dataframe['Product'], axis = 0).sum().plot(kind = 'pie');

# %% [markdown]
# #### Conclusion and recommendation

# %% [markdown]
# It doesn't appear that there is a significant difference between products TM195 and TM498 for both males and females as well as single and partnered customers. Males got more usage out of product TM798 compared to females. This also true for married males as well as single males.
#
# In conclusion product TM798 is favourable to income earners of over 40000, this should be marketed to these clientele, however more research is needed to understand why product TM798 is favoured by high income earners and consider ways to make it more accessible to other earners. This product is also favourable to partnered clientele. An important variable to explore would be the 'price' of each product. This will shed more light on other relationships between the attributes.
